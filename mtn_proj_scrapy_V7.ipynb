# %% [markdown]
# Mountain Project scraper
# Taylor Portman
# January 10, 2024

# %%
import scrapy
import pandas as pd
import json
import logging
import re
from scrapy.downloadermiddlewares.retry import RetryMiddleware

class MtnSpider(scrapy.Spider):
    name = 'mtnspider'
    start_urls = ['https://www.mountainproject.com/']
    area_data = []
    route_data = []
    stat_data = []

    custom_settings = {
        'DOWNLOAD_DELAY': 0.002, #avoid overloading the server with too many requests in a short period.
        'RETRY_HTTP_CODES': [429], #This specifies that the spider should retry requests that result in HTTP status code 429 (Too Many Requests)
        'RETRY_TIMES': 3,
        'USER_AGENTS': [ #The user-agent strings are simulated as if the requests are coming from different web browsers
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
        ],
    }

    # Parser 1: Collect by states + international + in progress from moutainproject homepage
    def parse(self, response):
        # Parse states and collect their URLs
        state_urls = response.css('#route-guide > div:nth-child(n) > div:nth-child(n) > strong > div > div:nth-child(n) > a::attr(href)').extract()
        state_name = response.css('#route-guide > div:nth-child(n) > div:nth-child(n) > strong > div > div:nth-child(n) > a::text').extract()

        for state_name, state_url in zip(state_name[3:], state_urls[3:]): 
                    # Send requests for state-specific pages while passing state_name as a meta parameter
            yield scrapy.Request(url=state_url, callback=self.parse_areas, meta={'state_name': state_name})

    def handle_request_error(self, failure):
        # Handle request errors here
        self.logger.error(f"Request error: {failure}")

    # Parser 2: For each state: IF areas/ sub areas collect urls and save identifier
    def parse_areas(self, response):
        state_name = response.meta.get('state_name')
        title = response.css('#climb-area-page > div > div.col-md-3.left-nav.float-md-left.mb-2 > div > h3::text').get()
        area_info_raw = response.css('#climb-area-page table tr td::text').extract()
        cleaned_text_area = ' '.join(map(str.strip, area_info_raw))
        area_id = None  # Initialize area_id with a default value
        route_id = None # Initialize route_id with a default value

        if title is not None and title.startswith("Areas"):
            area_urls = response.css('#climb-area-page > div > div.col-md-3.left-nav.float-md-left.mb-2 > div > div.max-height.max-height-md-0.max-height-xs-400 > div:nth-child(n) > a::attr(href)').extract()
            area_name = response.css('#climb-area-page > div > div.col-md-3.left-nav.float-md-left.mb-2 > div > div.max-height.max-height-md-0.max-height-xs-400 > div:nth-child(n) > a::text').extract()

            for area_url in area_urls:
                match_area = re.search(r'area/(\d+)', area_url)
                if match_area:
                    area_id = match_area.group(1)
                    yield {'area_id': area_id}
                else:
                    self.logger.warning("match_area pattern not found")

                for url, name in zip(area_urls, area_name):
                    yield scrapy.Request(
                        url=url,
                        callback=self.parse_areas,
                        meta={'state_name': state_name, 'area_name': name, 'area_id': area_id}
                    )

        elif title is not None and title.startswith("Routes"): #For each area collect routes and forward to parse_routes
            area_id = response.meta['area_id']
            area_name = response.meta['area_name']
            route_urls = response.css('#left-nav-route-table td:nth-child(n) a::attr(href)').extract()

            for route_url in route_urls:
                match_route = re.search(r'route/(\d+)', route_url)
                if match_route:
                    route_id = match_route.group(1)
                    yield {'route_id': route_id}
                else:
                    self.logger.warning("match_route pattern not found")

                route_name = response.css('#left-nav-route-table td:nth-child(n) a::text').extract()
    
                for url, name in zip(route_urls, route_name):
                    yield scrapy.Request(
                        url=url,
                        callback=self.parse_routes,
                        meta={'state_name': state_name, 'area_name': area_name, 'route_name': name, 'area_id': area_id, 'route_id': route_id}
                    )
        else: 
            self.logger.warning("Title element not found")

        ### Extract data from area page ###
        # Define regular expressions and corresponding field names
        patterns = [
             (r'Elevation:\s*([\d,]+)\s*ft', 'elevation_ft'),    # Match and extract route elevation
             (r'GPS:\s*(-?[\d.]+,\s*-?[\d.]+)', 'GPS')                        # Match and extract GPS data
             ]

        area_data = {}
        
        for pattern, field in patterns:
            match = re.search(pattern, cleaned_text_area)
            if match:
                area_data[field] = match.group(1).strip()
            else:
                    self.logger.warning("area_data pattern not found")

        yield area_data

        area_data['area_name'] = response.meta['area_name']
        area_data['state_name'] = response.meta['state_name']
        area_data['area_id'] = response.meta['area_id']
       

        self.area_data.append(area_data) 

    # Parser 3: For each area/ sub area: IF route then collect data
    def parse_routes(self, response):
        # Extract YDS grade
        gradeYDS = response.css('#route-page > div > div.col-md-9.float-md-right.mb-1 > h2 > span.rateYDS::text').extract()
        gradeYDS = gradeYDS[0] if gradeYDS else None

        # Extract Font grade
        gradeFont = response.css('#route-page > div > div.col-md-9.float-md-right.mb-1 > h2 > span.rateFont::text').extract()
        gradeFont = gradeFont[0] if gradeFont else None

        # Extract route information
        page_info_raw = response.css('#route-page table tr td::text').extract()
        cleaned_text = ' '.join(map(str.strip, page_info_raw))

        # Define regular expressions and corresponding field names
        patterns = [
            (r'Type:\s*([A-Za-z]+)', 'climb_type'),                   # Match and extract climb type
            (r'(\d+)\s*ft', 'climb_height_ft'),                       # Match and extract climb height in feet
            (r'\((\d+)\s*m\)', 'climb_height_m'),                     # Match and extract climb height in meters
            (r'FA:\s*([^:]+)(?= Page Views:|$)', 'first_ascent'),     # Match and extract First Ascent information
            (r'Page Views:\s*([\d,]+)', 'page_views_total'),           # Match and extract total page views
            (r'(\d+)/month', 'page_views_per_month')                  # Match and extract page views per month
        ]

        route_data = {}

        for pattern, field in patterns:
            match = re.search(pattern, cleaned_text)
            if match:
                route_data[field] = match.group(1).strip()
            else:
                    self.logger.warning("route_data pattern not found")
        # Assign YDS and Font grades
        route_data['gradeYDS'] = gradeYDS
        route_data['gradeFont'] = gradeFont

        # Add additional data fields
        route_data['state_name'] = response.meta['state_name']
        route_data['area_id'] = response.meta['area_id']
        route_data['area_name'] = response.meta['area_name']
        route_data['route_id'] = response.meta['route_id']
        route_data['route_name'] = response.meta['route_name']

        # Append the current route data to self.route_data
        self.route_data.append(route_data)

        #### Route stats parsing from route page:
        route_id = response.meta.get('route_id')
        stat_data = {'route_id': route_id, 'avg_stars': None, 'num_votes': None}  # Initialize with default values
        # Extract stars and num votes from route stats info
        avg_stars_votes = response.xpath('//*[starts-with(@id, "starsWithAvgText-")]/text()').extract()
        for element in avg_stars_votes:
            # Extracting and cleaning the text from each matched element
            cleaned_text = ' '.join(avg_stars_votes).strip()

            # Define a regular expression pattern to match "Avg: X.X from Y votes" format
            pattern = r'Avg:\s*([\d.]+)\s*from\s*(\d+)\s*votes'

            # Use re.search to find the pattern in the text
            match = re.search(pattern, cleaned_text)

            # Check if a match was found
            if match:
                # Extract avg_stars (the first group) and convert it to a float
                avg_stars = float(match.group(1))

                # Extract num_votes (the second group) and convert it to an integer
                num_votes = int(match.group(2))

                stat_data = {
                    'route_id': route_id,
                    'avg_stars': avg_stars,
                    'num_votes': num_votes
                }
            else:
                    self.logger.warning("avg_stars, num_votes pattern not found")

        # Append the collected stat data to self.stat_data
        self.stat_data.append(stat_data)


    def closed(self, reason):
        try: 
            # Save route data as JSON
            json_route = json.dumps(self.route_data, indent=2)
            with open('route_data.json', 'w') as json_route_file:
                json_route_file.write(json_route)

            # Save area data as JSON
            json_area = json.dumps(self.area_data, indent=2)
            with open('area_data.json', 'w') as json_area_file:
                json_area_file.write(json_area)

            # Save stat data as JSON
            json_stat = json.dumps(self.stat_data, indent=2)
            with open('stat_data.json', 'w') as json_stat_file:
                json_stat_file.write(json_stat)
        except Exception as e:
            self.logger.error(f"Error while saving JSON data: {str(e)}")

# %%
from scrapy.crawler import CrawlerProcess
process = CrawlerProcess()
process.crawl(MtnSpider)
process.start()
# Out:
# 2024-01-10 13:31:09 [scrapy.utils.log] INFO: Scrapy 2.10.1 started (bot: scrapybot)
# 2024-01-10 13:31:09 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.9.18 (main, Sep 11 2023, 08:38:23) - [Clang 14.0.6 ], pyOpenSSL 23.2.0 (OpenSSL 3.1.2 1 Aug 2023), cryptography 41.0.3, Platform macOS-10.16-x86_64-i386-64bit
# 2024-01-10 13:31:09 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-10 13:31:09 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 0.002, 'RETRY_HTTP_CODES': [429], 'RETRY_TIMES': 3}
# 2024-01-10 13:31:09 [py.warnings] WARNING: /Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/request.py:248: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-01-10 13:31:09 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-01-10 13:31:09 [scrapy.extensions.telnet] INFO: Telnet Password: e91db78712c4a561
# 2024-01-10 13:31:09 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-10 13:31:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-10 13:31:09 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-10 13:31:09 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-10 13:31:09 [scrapy.core.engine] INFO: Spider opened
# 2024-01-10 13:31:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-10 13:31:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2024-01-10 13:31:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/> (referer: None)
# 2024-01-10 13:31:09 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.mountainproject.com/area/105901027/arkansas> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2024-01-10 13:31:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105901027/arkansas> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105909311/alaska> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708968/wisconsin> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105901027/arkansas>
# {'area_id': '119612630'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105901027/arkansas>
# {'area_id': '119612563'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105901027/arkansas>
# {'area_id': '118730582'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105901027/arkansas>
# {'area_id': '118733296'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105901027/arkansas>
# {'elevation_ft': '868', 'GPS': '36.00689, -93.18812'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105901027/arkansas> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905072'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930712'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905115'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905110'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '124871926'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '105730021'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930678'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930669'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930655'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905088'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '123904010'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905120'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '108268674'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105855459/west-virginia> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930693'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'area_id': '119930700'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708968/wisconsin>
# {'elevation_ft': '1,221', 'GPS': '44.46518, -89.47268'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105708968/wisconsin> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '106905123'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'area_id': '108406032'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105909311/alaska>
# {'elevation_ft': '600', 'GPS': '64.73659, -150.73238'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105909311/alaska> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'area_id': '121909207'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105798164/in-progress> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708962/arizona> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105905173/alabama> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'area_id': '105855991'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'area_id': '121909189'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'area_id': '105861910'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'area_id': '121909197'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105855459/west-virginia>
# {'elevation_ft': '1,000', 'GPS': '38.06919, -81.08119'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105907743/international> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105855459/west-virginia> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708960/wyoming> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '121959017'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708966/washington> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708962/arizona>
# {'area_id': '107447478'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '107605102'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '106135596'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '109083830'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/106842810/rhode-island> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708962/arizona>
# {'area_id': '107447440'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708962/arizona>
# {'area_id': '107447521'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708962/arizona>
# {'elevation_ft': '3,816', 'GPS': '34.37969, -112.06098'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105708962/arizona> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '106248455'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '113864722'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '107717786'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '124923731'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105887760/tennessee> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '120425602'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471474'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '106661515'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '105907756'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '106660030'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '106419259'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '111214399'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105852400/virginia> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '123330114'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471397'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471374'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471503'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '106661469'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '107833406'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'area_id': '106661603'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '107835264'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '124098334'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471385'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471485'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105907743/international>
# {'elevation_ft': '1,020', 'GPS': '21.943, 81.56249'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105907743/international> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '106157878'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '125437520'}
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708957/utah> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105891603/vermont> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105913279/pennsylvania> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '121896878'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '107478460'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471326'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471467'}
# 2024-01-10 13:31:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471329'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105887760/tennessee>
# {'area_id': '106881426'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '105714267'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '125389652'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '106833394'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '107114464'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105852400/virginia>
# {'area_id': '109847004'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'area_id': '108471509'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708966/washington>
# {'elevation_ft': '5,664', 'GPS': '47.39828, -120.76195'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105708966/washington> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '106366047'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '110773697'}
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/107638915/south-carolina> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105861910/seneca-rocks> (referer: https://www.mountainproject.com/area/105855459/west-virginia)
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/121909189/northern-wv> (referer: https://www.mountainproject.com/area/105855459/west-virginia)
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '109749052'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '106890252'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105852400/virginia>
# {'area_id': '110848223'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105852400/virginia>
# {'area_id': '110848216'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105852400/virginia>
# {'area_id': '110848199'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105852400/virginia>
# {'elevation_ft': '1,455', 'GPS': '36.90506, -80.14423'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105887760/tennessee>
# {'area_id': '111947944'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '124473842'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '119375690'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '123505845'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '112857573'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105891603/vermont>
# {'area_id': '107280521'}
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105708963/south-dakota> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/105835804/texas> (referer: https://www.mountainproject.com/)
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/index.php/area/119930700/south> (referer: https://www.mountainproject.com/area/105708968/wisconsin)
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105913279/pennsylvania>
# {'area_id': '109481682'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '125458407'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '122743437'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/106842810/rhode-island>
# {'area_id': '106891059'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105852400/virginia> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/var/folders/xx/6ny9g9kx68zc6_psqd5f6d540000gn/T/ipykernel_66654/2864123321.py", line 108, in parse_areas
#     area_data['area_name'] = response.meta['area_name']
# KeyError: 'area_name'
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '105825913'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '119375779'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '119375770'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '105716711'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '119375710'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105798164/in-progress>
# {'area_id': '113061209'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105891603/vermont>
# {'area_id': '119666432'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105891603/vermont>
# {'area_id': '119666460'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105891603/vermont>
# {'area_id': '119666468'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105891603/vermont>
# {'elevation_ft': '880', 'GPS': '44.24715, -72.57844'}
# 2024-01-10 13:31:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.mountainproject.com/area/121909197/southern-wv> (referer: https://www.mountainproject.com/area/105855459/west-virginia)
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105913279/pennsylvania>
# {'area_id': '109481543'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105905173/alabama>
# {'area_id': '106222485'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708960/wyoming>
# {'area_id': '105802912'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '105739213'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105708957/utah>
# {'area_id': '112409907'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/107638915/south-carolina>
# {'area_id': '119797520'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/105861910/seneca-rocks>
# {'area_id': '106282056'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.mountainproject.com/area/121909189/northern-wv>
# {'area_id': '116651990'}
# 2024-01-10 13:31:11 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.mountainproject.com/area/105891603/vermont> (referer: https://www.mountainproject.com/)
# Traceback (most recent call last):
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/defer.py", line 277, in iter_errback
#     yield next(it)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "/Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
# ...
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106169626/continental-ranch> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106160063/camp-eagle> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/107217388/brownwood> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/107436412/caprock-canyons-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/117882984/brazos-river-boulders> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116711736/austin-area> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106192146/big-bend-national-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/122435022/bailey-hollow> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/114178692/adair-springs> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105714282/spearfish-canyon> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112521748/southern-black-hills> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112521661/rapid-city-area> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112521727/the-needles-of-rushmore> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106058091/custer-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112521712/east-side-sd> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109019242/the-marina> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105714309/crow-peak> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/123643436/valley-falls-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/120215157/northern-panhandle> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/108890544/north-bend-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/107035297/coopers-rock-state-forest> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105868456/south-peak-east-face> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116651990/cheat-canyon> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105868490/southern-pillar> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105861915/south-peak-west-face> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105910040/north-peak-west-face> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106058476/north-peak-east-face> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105868483/south-end> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105855466/lower-slabs> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106282056/the-cave> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112245095/savannah-river-mini-quarry> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119449313/table-rock-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/111819977/rocky-creek-bouldering> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/123558970/poe-mill> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:05 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/124674777/persimmon-ridge-bouldering-area> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/114070728/poinsett-bridge-bouldering> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/125332088/furman-university> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/113573351/big-rock-mountain> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/108310273/jocassee-gorges-bouldering> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/123163555/cayce-riverwalk> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119797520/asbury-hills> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110570379/the-northwest> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109481543/northeast-ridges-and-valleys> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109481375/south-central-pa> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109478733/southeastern-lowlands> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119666468/southern-vermont> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119666460/central-vermont> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109481682/central-pa> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119666432/northern-vermont> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119375770/south-central-utah> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/107280521/vt-ice-and-mixed> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119375779/northeast-utah> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106517729/toxic-wall> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105716711/southeast-utah> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119375690/central-utah> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105851828/the-tennessee-wall> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116731219/taylor-creek-gourge> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/125027396/waldens-ridge-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/122396982/tennessee-river-deep-water-soloing> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105888070/sunset-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116688247/tweetsie-trail-railroad-cuts> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/114423751/sucka-cave> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106093571/stone-door-at-savage-gulf-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106032735/suck-creek-canyon> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/113993749/stillhouse-hollow-falls-ice-climbing> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106031921/stone-fort> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105892905/starr-mountain> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116131724/river-wall> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110852444/short-mountain> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110855732/prentice-cooper> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/118986900/phil-rock> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/116698643/percy-priest-dws> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/114223257/north-chick-gorge-soddy-tn> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/117283884/panther-creek-state-park> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/105891970/obed-clear-creek> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110848199/southwest-virginia-appalachia> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110848216/shenandoah-nw-va-region> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/110848223/dc-northern-va-region> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/109847004/central-southern-va-region> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:06 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/124180012/narrows-of-the-harpeth> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106823521/norris-lake> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119952227/monterey-crag> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/111922474/nolichucky-riverside> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/119977233/middle-creek> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/112080944/mizell-bluffs-on-tellico-lake> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/123667014/lower-station-camp-rail-wall> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/106189076/lower-leda> (failed 3 times): 429 Unknown Status
# 2024-01-10 13:34:07 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.mountainproject.com/area/123419763/lookout-mountain> (failed 3 times): 429 Unknown Status
