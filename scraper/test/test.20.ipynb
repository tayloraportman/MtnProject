# %% [markdown]
# Taylor Portman
# 1/17/24
#
# MtnSpider Test
# Select 5 random areas
# Collect data from all routes at each area

# %%
import unittest
import random
import json
import sys
sys.path.append('/Users/tayloraportman/Desktop/MtnProject')
from scraper.mtn_proj_scrapy_all import MtnSpider  # Import your spider
from scrapy.crawler import CrawlerProcess

class TestMtnSpider(unittest.TestCase):
    def setUp(self):
        # Set up the Scrapy crawler process
        self.process = CrawlerProcess(

        custom_settings = {
                'DOWNLOAD_DELAY': 0.002, #avoid overloading the server with too many requests in a short period.
                'RETRY_HTTP_CODES': [429], #This specifies that the spider should retry requests that result in HTTP status code 429 (Too Many Requests)
                'RETRY_TIMES': 3,
                'USER_AGENTS': [ #The user-agent strings are simulated as if the requests are coming from different web browsers
                    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
                ],
            })
        self.spider = MtnSpider  # The spider you want to test

    def test_scrape_random_areas(self):
        with open('route_urls.json', 'r') as file:
            route_urls = json.load(file)

        # Randomly select 5 areas
        selected_routes = random.sample(route_urls, 20)

        # Schedule crawls for each selected area
        for route_urls in selected_routes:
            self.process.crawl(self.spider, callback=self.spider.parse_areas, start_urls=[route_urls])

        # Start the crawling process only once
        self.process.start()

        # Additional code to check results or perform validations can be added here
# Out:
# 2024-01-17 20:37:48 [scrapy.utils.log] INFO: Scrapy 2.10.1 started (bot: scrapybot)
# 2024-01-17 20:37:48 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.9.18 (main, Sep 11 2023, 08:38:23) - [Clang 14.0.6 ], pyOpenSSL 23.2.0 (OpenSSL 3.1.2 1 Aug 2023), cryptography 41.0.3, Platform macOS-10.16-x86_64-i386-64bit
# 2024-01-17 20:37:48 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-17 20:37:48 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 0.002, 'RETRY_HTTP_CODES': [429], 'RETRY_TIMES': 3}
# 2024-01-17 20:37:48 [py.warnings] WARNING: /Users/tayloraportman/opt/anaconda3/envs/learning_scrapy/lib/python3.9/site-packages/scrapy/utils/request.py:248: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %%
if __name__ == '__main__':
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument '/Users/tayloraportman/Library/Jupyter/runtime/kernel-v2-13282Nej4Hn0tNqbF.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/learning_scrapy/lib/python3.9/argparse.py:1858, in ArgumentParser.parse_known_args(self, args, namespace)
#    1857 try:
# -> 1858     namespace, args = self._parse_known_args(args, namespace)
#    1859 except ArgumentError:
#
# File ~/opt/anaconda3/envs/learning_scrapy/lib/python3.9/argparse.py:2067, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2066     # consume the next optional and any arguments for it
# ...
